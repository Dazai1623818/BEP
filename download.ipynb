# %%
import requests
import gzip
import os
from bs4 import BeautifulSoup
import re


API_KEY = os.environ['API_KEY']
url = f'https://gz.blockchair.com/bitcoin/transactions/?key={API_KEY}'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    links = soup.find_all('a')
    for link in links:
        href = link.get('href')
        if href:
            # filter out parent directory links and other non-file links
            if re.match(r'^[^/?]*\.[^/?]*$', href):
                print(href)
# Out:
# blockchair_bitcoin_transactions_20090103.tsv.gz
# blockchair_bitcoin_transactions_20090109.tsv.gz
# blockchair_bitcoin_transactions_20090110.tsv.gz
# blockchair_bitcoin_transactions_20090111.tsv.gz
# blockchair_bitcoin_transactions_20090112.tsv.gz
# blockchair_bitcoin_transactions_20090113.tsv.gz
# blockchair_bitcoin_transactions_20090114.tsv.gz
# blockchair_bitcoin_transactions_20090115.tsv.gz
# blockchair_bitcoin_transactions_20090116.tsv.gz
# blockchair_bitcoin_transactions_20090117.tsv.gz
# blockchair_bitcoin_transactions_20090118.tsv.gz
# blockchair_bitcoin_transactions_20090119.tsv.gz
# blockchair_bitcoin_transactions_20090120.tsv.gz
# blockchair_bitcoin_transactions_20090121.tsv.gz
# blockchair_bitcoin_transactions_20090122.tsv.gz
# blockchair_bitcoin_transactions_20090123.tsv.gz
# blockchair_bitcoin_transactions_20090124.tsv.gz
# blockchair_bitcoin_transactions_20090125.tsv.gz
# blockchair_bitcoin_transactions_20090126.tsv.gz
# blockchair_bitcoin_transactions_20090127.tsv.gz
# ...

# %%
links
# Out:
# [<a href="https://blockchair.com/"><img src="https://blockchair.com/images/logo_full.png" style="width: 229px; height: auto; max-width: 100%;"/></a>,
#  <a href="https://blockchair.com/dumps">Description</a>,
#  <a href="https://gz.blockchair.com/README.html">Lift the speed limit</a>,
#  <a href="../">../</a>,
#  <a href="blockchair_bitcoin_transactions_20090103.tsv.gz">blockchair_bitcoin_transactions_20090103.tsv.gz</a>,
#  <a href="blockchair_bitcoin_transactions_20090109.tsv.gz">blockchair_bitcoin_transactions_20090109.tsv.gz</a>,
#  <a href="blockchair_bitcoin_transactions_20090110.tsv.gz">blockchair_bitcoin_transactions_20090110.tsv.gz</a>,
#  <a href="blockchair_bitcoin_transactions_20090111.tsv.gz">blockchair_bitcoin_transactions_20090111.tsv.gz</a>,
#  <a href="blockchair_bitcoin_transactions_20090112.tsv.gz">blockchair_bitcoin_transactions_20090112.tsv.gz</a>,
#  <a href="blockchair_bitcoin_transactions_20090113.tsv.gz">blockchair_bitcoin_transactions_20090113.tsv.gz</a>,
# ...

# %%
url = f'https://gz.blockchair.com/bitcoin/addresses/blockchair_bitcoin_addresses_latest.tsv.gz?key={API_KEY}'
filename = 'addresses'

response = requests.get(url)
with open(filename, 'wb') as f:
    f.write(response.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File c:\Users\thepi\anaconda3\envs\Quant\lib\site-packages\urllib3\response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# File c:\Users\thepi\anaconda3\envs\Quant\lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#
# File c:\Users\thepi\anaconda3\envs\Quant\lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     531 else:
#     532     # StringIO doesn't like amt=None
# ...
